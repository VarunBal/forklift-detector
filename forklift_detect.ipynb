# %%
#GPU details
# !nvidia-smi
# Out:
# Thu Jan 30 13:49:58 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.44       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   32C    P0    25W / 250W |      0MiB / 16280MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# ...

# %%
#clone darknet repo
# !git clone https://github.com/AlexeyAB/darknet.git
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 12428, done.
# remote: Total 12428 (delta 0), reused 0 (delta 0), pack-reused 12428
# Receiving objects: 100% (12428/12428), 11.48 MiB | 12.49 MiB/s, done.
# Resolving deltas: 100% (8450/8450), done.

# %%
#mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
#change directory to darknet
# %cd ./darknet
# Out:
# /content/darknet

# %%
#install opencv
# !apt-get install python3-opencv
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-430
# Use 'apt autoremove' to remove it.
# The following NEW packages will be installed:
#   python3-opencv
# 0 upgraded, 1 newly installed, 0 to remove and 7 not upgraded.
# Need to get 534 kB of archives.
# After this operation, 2,941 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 python3-opencv amd64 3.2.0+dfsg-4ubuntu0.1 [534 kB]
# Fetched 534 kB in 0s (5,831 kB/s)
# Selecting previously unselected package python3-opencv.
# (Reading database ... 145674 files and directories currently installed.)
# Preparing to unpack .../python3-opencv_3.2.0+dfsg-4ubuntu0.1_amd64.deb ...
# Unpacking python3-opencv (3.2.0+dfsg-4ubuntu0.1) ...
# Setting up python3-opencv (3.2.0+dfsg-4ubuntu0.1) ...

# %%
#replace darknet makefiles with custom makefile
# !cp ../Makefile Makefile

# %%
#install darknet
# !make
# Out:
# mkdir -p ./obj/
# mkdir -p backup
# mkdir -p results
# chmod +x *.sh
# g++ -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:909:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# g++ -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/http_stream.cpp -o obj/http_stream.o
# In file included from ./src/http_stream.cpp:576:0:
# ./src/httplib.h:129:0: warning: "INVALID_SOCKET" redefined
# ...

# %%
#test darknet
# !./darknet
# Out:
# usage: ./darknet <function>

# %%
#copying training data from Gdrive to running instance to reduce IO lag
# !cp -r "/content/drive/My Drive/train_data" /content/darknet/data/fork_lift

# %%
#create soft link to grive to save training models directly to drive
# !ln -s "/content/drive/My Drive/train_backup/" /content/darknet/backup/

# %%
#install dos2unix to copy windows files with proper linux format
# !apt install dos2unix
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-430
# Use 'apt autoremove' to remove it.
# The following NEW packages will be installed:
#   dos2unix
# 0 upgraded, 1 newly installed, 0 to remove and 7 not upgraded.
# Need to get 351 kB of archives.
# After this operation, 1,267 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 dos2unix amd64 7.3.4-3 [351 kB]
# Fetched 351 kB in 0s (4,459 kB/s)
# Selecting previously unselected package dos2unix.
# (Reading database ... 145678 files and directories currently installed.)
# Preparing to unpack .../dos2unix_7.3.4-3_amd64.deb ...
# Unpacking dos2unix (7.3.4-3) ...
# Setting up dos2unix (7.3.4-3) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...

# %%
#coping uploaded project files to working directory
# !dos2unix -n /content/forklift.data cfg/forklift.data
# !dos2unix -n /content/yolo_custom.cfg cfg/yolo_custom.cfg
# !dos2unix -n /content/train.txt data/forklift_train.txt
# !dos2unix -n /content/test.txt data/forklift_test.txt
# !dos2unix -n /content/labels.txt data/forklift_labels.txt
# Out:
# dos2unix: converting file /content/forklift.data to file cfg/forklift.data in Unix format...
# dos2unix: converting file /content/yolo_custom.cfg to file cfg/yolo_custom.cfg in Unix format...
# dos2unix: converting file /content/train.txt to file data/forklift_train.txt in Unix format...
# dos2unix: converting file /content/test.txt to file data/forklift_test.txt in Unix format...
# dos2unix: converting file /content/labels.txt to file data/forklift_labels.txt in Unix format...

# %%
#evaluate trained model
# !./darknet detector map cfg/forklift.data cfg/yolo_custom.cfg backup/train_backup/yolo_custom_4200.weights
# Out:
#  CUDA-version: 10000 (10010)
# ...
# , GPU count: 1
#  OpenCV version: 3.2.0
# net.optimized_memory = 0
# batch = 1, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    800 x 800 x   3 ->  800 x 800 x  32 1.106 BF
#    1 conv     64       3 x 3/ 2    800 x 800 x  32 ->  400 x 400 x  64 5.898 BF
#    2 conv     32       1 x 1/ 1    400 x 400 x  64 ->  400 x 400 x  32 0.655 BF
#    3 conv     64       3 x 3/ 1    400 x 400 x  32 ->  400 x 400 x  64 5.898 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 400 x 400 x  64 0.010 BF
#    5 conv    128       3 x 3/ 2    400 x 400 x  64 ->  200 x 200 x 128 5.898 BF
#    6 conv     64       1 x 1/ 1    200 x 200 x 128 ->  200 x 200 x  64 0.655 BF
#    7 conv    128       3 x 3/ 1    200 x 200 x  64 ->  200 x 200 x 128 5.898 BF
#    8 Shortcut Layer: 5,  wt = 0, wn = 0, outputs: 200 x 200 x 128 0.005 BF
# ...

# %%
#Run detection on uploaded test images
# !./darknet detector test cfg/forklift.data cfg/yolo_custom.cfg backup/train_backup/yolo_custom_final.weights /content/test/Capture8.jpg -thresh 0.09
# Out:
#  CUDA-version: 10000 (10010)
# ...
# , GPU count: 1
#  OpenCV version: 3.2.0
# net.optimized_memory = 0
# batch = 1, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    800 x 800 x   3 ->  800 x 800 x  32 1.106 BF
#    1 conv     64       3 x 3/ 2    800 x 800 x  32 ->  400 x 400 x  64 5.898 BF
#    2 conv     32       1 x 1/ 1    400 x 400 x  64 ->  400 x 400 x  32 0.655 BF
#    3 conv     64       3 x 3/ 1    400 x 400 x  32 ->  400 x 400 x  64 5.898 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 400 x 400 x  64 0.010 BF
#    5 conv    128       3 x 3/ 2    400 x 400 x  64 ->  200 x 200 x 128 5.898 BF
#    6 conv     64       1 x 1/ 1    200 x 200 x 128 ->  200 x 200 x  64 0.655 BF
#    7 conv    128       3 x 3/ 1    200 x 200 x  64 ->  200 x 200 x 128 5.898 BF
#    8 Shortcut Layer: 5,  wt = 0, wn = 0, outputs: 200 x 200 x 128 0.005 BF
# ...

# %%
#install ffmpeg to help run detection for video
# !apt-get install ffmpeg
# !wget http://launchpadlibrarian.net/348889634/libav-tools_3.4.1-1_all.deb
# !dpkg -i libav-tools_3.4.1-1_all.deb
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# ffmpeg is already the newest version (7:3.4.6-0ubuntu0.18.04.1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-430
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 7 not upgraded.
# --2020-01-30 13:54:07--  http://launchpadlibrarian.net/348889634/libav-tools_3.4.1-1_all.deb
# Resolving launchpadlibrarian.net (launchpadlibrarian.net)... 91.189.89.229, 91.189.89.228, 2001:67c:1560:8003::8007, ...
# Connecting to launchpadlibrarian.net (launchpadlibrarian.net)|91.189.89.229|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 15844 (15K) [application/x-debian-package]
# Saving to: ‘libav-tools_3.4.1-1_all.deb’
#
# libav-tools_3.4.1-1 100%[===================>]  15.47K  --.-KB/s    in 0.01s
#
# 2020-01-30 13:54:08 (1.41 MB/s) - ‘libav-tools_3.4.1-1_all.deb’ saved [15844/15844]
#
# ...

# %%
#copy helper file to working directory for detection on video
# !dos2unix -n /content/predict_to_vid.sh predict_to_vid
# !chmod u+x predict_to_vid
# Out:
# dos2unix: converting file /content/predict_to_vid.sh to file predict_to_vid in Unix format...

# %%
#run detection on uploaded video
# !/content/darknet/predict_to_vid /content/test/forklift_test_video_2.mp4
# Out:
#  CUDA-version: 10000 (10010)
# ...
# , GPU count: 1
#  OpenCV version: 3.2.0
# Demo
# net.optimized_memory = 0
# batch = 1, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    800 x 800 x   3 ->  800 x 800 x  32 1.106 BF
#    1 conv     64       3 x 3/ 2    800 x 800 x  32 ->  400 x 400 x  64 5.898 BF
#    2 conv     32       1 x 1/ 1    400 x 400 x  64 ->  400 x 400 x  32 0.655 BF
#    3 conv     64       3 x 3/ 1    400 x 400 x  32 ->  400 x 400 x  64 5.898 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 400 x 400 x  64 0.010 BF
#    5 conv    128       3 x 3/ 2    400 x 400 x  64 ->  200 x 200 x 128 5.898 BF
#    6 conv     64       1 x 1/ 1    200 x 200 x 128 ->  200 x 200 x  64 0.655 BF
#    7 conv    128       3 x 3/ 1    200 x 200 x  64 ->  200 x 200 x 128 5.898 BF
#    8 Shortcut Layer: 5,  wt = 0, wn = 0, outputs: 200 x 200 x 128 0.005 BF
# ...
